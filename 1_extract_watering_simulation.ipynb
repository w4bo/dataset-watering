# %%
from shared import *

# Replace these values with your database connection details
db_params = {
    'host': config["IN_HOST"],
    'database': config["IN_DB"],
    'user': config["IN_USER"],
    'password': config["IN_PWD"],
    'port': config["IN_PORT"]
}

engine = get_engine(db_params)
engine
# Out:
# postgresql+psycopg2://root:root@127.0.0.1:5432/db
# {'dt_field': {'col': ['field', 'province', 'region', 'country']},
#  'dt_time': {'col': ['timestamp',
#    'datetime',
#    'hour',
#    'date',
#    'month',
#    'year']},
#  'dt_agent': {'col': ['agent', 'agentType', 'agentHier']},
#  'ft_measurement': {'col': ['agent',
#    'type',
#    'field',
#    'owner',
#    'project',
#    'timestamp',
#    'value',
#    'delay']}}

# %%
# SQL query to select all data from the table
sql_query = f"""
select * from (
select
	'Field-' || right(md5(d.field_name || s."name" || s.description || s.scenario_arpae_name || s.scenario_water_name), 10) as field,
    d.field_name as fielddesc, s."name" as scenario, s.description as scenario_description, s.scenario_arpae_name as arpae, s.scenario_water_name as watering, 
	d.unix_timestamp as sensor_timestamp, d.value_type_name as sensor_type, d.x as sensor_x, d.y as sensor_y, d.z as sensor_z, d.value as sensor_value
from synthetic_data d, synthetic_field f, synthetic_scenario s
where d.field_name = f."name" and d.scenario_name = s."name"
) where field = 'Field-0d02000d12'
"""
#limit 10000
# Use pandas to read the query result into a DataFrame
df = pd.read_sql(sql_query, engine)

# Now 'df' contains the data from the PostgreSQL table
df.to_csv('data/sensor_ft.csv', index=False)
df
# Out:
#                    field                       fielddesc  \
# 0       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                  ...                             ...
# 354595  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354596  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354597  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354598  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354599  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                             scenario  \
# 0       Synthetic Bologna 2019 v.2.0
# 1       Synthetic Bologna 2019 v.2.0
# 2       Synthetic Bologna 2019 v.2.0
# 3       Synthetic Bologna 2019 v.2.0
# 4       Synthetic Bologna 2019 v.2.0
# ...                              ...
# 354595  Synthetic Bologna 2019 v.2.0
# 354596  Synthetic Bologna 2019 v.2.0
# 354597  Synthetic Bologna 2019 v.2.0
# 354598  Synthetic Bologna 2019 v.2.0
# 354599  Synthetic Bologna 2019 v.2.0
#
#                                      scenario_description              arpae  \
# 0       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                   ...                ...
# 354595  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354596  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354597  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354598  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354599  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                             watering  sensor_timestamp  \
# 0       Synthetic Bologna 2019 v.2.0        1569193200
# 1       Synthetic Bologna 2019 v.2.0        1569196800
# 2       Synthetic Bologna 2019 v.2.0        1569200400
# 3       Synthetic Bologna 2019 v.2.0        1569204000
# 4       Synthetic Bologna 2019 v.2.0        1569207600
# ...                              ...               ...
# 354595  Synthetic Bologna 2019 v.2.0        1569175200
# 354596  Synthetic Bologna 2019 v.2.0        1569178800
# 354597  Synthetic Bologna 2019 v.2.0        1569182400
# 354598  Synthetic Bologna 2019 v.2.0        1569186000
# 354599  Synthetic Bologna 2019 v.2.0        1569189600
#
#                      sensor_type  sensor_x  sensor_y  sensor_z  sensor_value
# 0       GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 1       GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 2       GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1201
# 3       GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1201
# 4       GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1201
# ...                          ...       ...       ...       ...           ...
# 354595  GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 354596  GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 354597  GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 354598  GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
# 354599  GROUND_SATURATION_DEGREE       0.9       0.0      -0.6        0.1200
#
# [354600 rows x 12 columns]

# %%
# SQL query to select all data from the table
sql_query = f"""
select * from (
select
	'Field-' || right(md5(sf.field_name || s."name" || s.description || s.scenario_arpae_name || s.scenario_water_name), 10) as field,
    sf.field_name as fielddesc, s."name" as scenario, s.description as scenario_description, s.scenario_arpae_name as arpae, s.scenario_water_name as watering,
	da.unix_timestamp as arpae_timestamp, da.value_type_name as arpae_type, da.value as arpae_value, null as x, null as y, null as z
from synthetic_field_scenario sf, synthetic_scenario s, synthetic_scenario_arpae_data da
where sf.scenario_name = s."name" and s.scenario_arpae_name = da.scenario_arpae_name
) where field = 'Field-0d02000d12'
"""

# Use pandas to read the query result into a DataFrame
df = pd.read_sql(sql_query, engine)

# Now 'df' contains the data from the PostgreSQL table
df.to_csv('data/weather_ft.csv', index=False)
df
# Out:
#                   field                       fielddesc  \
# 0      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                 ...                             ...
# 14770  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14771  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14772  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14773  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14774  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                            scenario  \
# 0      Synthetic Bologna 2019 v.2.0
# 1      Synthetic Bologna 2019 v.2.0
# 2      Synthetic Bologna 2019 v.2.0
# 3      Synthetic Bologna 2019 v.2.0
# 4      Synthetic Bologna 2019 v.2.0
# ...                             ...
# 14770  Synthetic Bologna 2019 v.2.0
# 14771  Synthetic Bologna 2019 v.2.0
# 14772  Synthetic Bologna 2019 v.2.0
# 14773  Synthetic Bologna 2019 v.2.0
# 14774  Synthetic Bologna 2019 v.2.0
#
#                                     scenario_description              arpae  \
# 0      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                  ...                ...
# 14770  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14771  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14772  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14773  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14774  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                            watering  arpae_timestamp      arpae_type  \
# 0      Synthetic Bologna 2019 v.2.0       1559340000  PRECIPITATIONS
# 1      Synthetic Bologna 2019 v.2.0       1559343600  PRECIPITATIONS
# 2      Synthetic Bologna 2019 v.2.0       1559347200  PRECIPITATIONS
# 3      Synthetic Bologna 2019 v.2.0       1559350800  PRECIPITATIONS
# 4      Synthetic Bologna 2019 v.2.0       1559354400  PRECIPITATIONS
# ...                             ...              ...             ...
# 14770  Synthetic Bologna 2019 v.2.0       1569960000      WIND_SPEED
# 14771  Synthetic Bologna 2019 v.2.0       1569963600      WIND_SPEED
# 14772  Synthetic Bologna 2019 v.2.0       1569967200      WIND_SPEED
# 14773  Synthetic Bologna 2019 v.2.0       1569970800      WIND_SPEED
# 14774  Synthetic Bologna 2019 v.2.0       1569974400      WIND_SPEED
#
#        arpae_value     x     y     z
# 0              0.0  None  None  None
# 1              0.0  None  None  None
# 2              0.0  None  None  None
# 3              0.0  None  None  None
# 4              0.0  None  None  None
# ...            ...   ...   ...   ...
# 14770          2.8  None  None  None
# 14771          2.6  None  None  None
# 14772          3.1  None  None  None
# 14773          5.1  None  None  None
# 14774          4.0  None  None  None
#
# [14775 rows x 12 columns]

# %%
# SQL query to select all data from the table
sql_query = f"""
select * from (
select
	'Field-' || right(md5(sf.field_name || s."name" || s.description || s.scenario_arpae_name || s.scenario_water_name), 10) as field,
    sf.field_name as fielddesc, s."name" as scenario, s.description as scenario_description, s.scenario_arpae_name as arpae, s.scenario_water_name as watering, 
	dw.unix_timestamp as water_timestamp, dw.value_type_name as water_type, dw.value as water_value, null as x, null as y, null as z
from synthetic_field_scenario sf, synthetic_scenario s, synthetic_scenario_water_data dw
where sf.scenario_name = s."name" and s.scenario_water_name = dw.scenario_water_name
) where field = 'Field-0d02000d12'
"""

# Use pandas to read the query result into a DataFrame
df = pd.read_sql(sql_query, engine)

# Now 'df' contains the data from the PostgreSQL table
df.to_csv('data/irrigation_ft.csv', index=False)
df
# Out:
#                  field                       fielddesc  \
# 0     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                ...                             ...
# 2950  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2951  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2952  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2953  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2954  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                           scenario  \
# 0     Synthetic Bologna 2019 v.2.0
# 1     Synthetic Bologna 2019 v.2.0
# 2     Synthetic Bologna 2019 v.2.0
# 3     Synthetic Bologna 2019 v.2.0
# 4     Synthetic Bologna 2019 v.2.0
# ...                            ...
# 2950  Synthetic Bologna 2019 v.2.0
# 2951  Synthetic Bologna 2019 v.2.0
# 2952  Synthetic Bologna 2019 v.2.0
# 2953  Synthetic Bologna 2019 v.2.0
# 2954  Synthetic Bologna 2019 v.2.0
#
#                                    scenario_description              arpae  \
# 0     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                 ...                ...
# 2950  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2951  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2952  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2953  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2954  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                           watering  water_timestamp   water_type  water_value  \
# 0     Synthetic Bologna 2019 v.2.0       1559340000  IRRIGATIONS          0.0
# 1     Synthetic Bologna 2019 v.2.0       1559343600  IRRIGATIONS          0.0
# 2     Synthetic Bologna 2019 v.2.0       1559347200  IRRIGATIONS          0.0
# 3     Synthetic Bologna 2019 v.2.0       1559350800  IRRIGATIONS          0.0
# 4     Synthetic Bologna 2019 v.2.0       1559354400  IRRIGATIONS          0.0
# ...                            ...              ...          ...          ...
# 2950  Synthetic Bologna 2019 v.2.0       1569960000  IRRIGATIONS          0.0
# 2951  Synthetic Bologna 2019 v.2.0       1569963600  IRRIGATIONS          0.0
# 2952  Synthetic Bologna 2019 v.2.0       1569967200  IRRIGATIONS          0.0
# 2953  Synthetic Bologna 2019 v.2.0       1569970800  IRRIGATIONS          0.0
# 2954  Synthetic Bologna 2019 v.2.0       1569974400  IRRIGATIONS          0.0
#
#          x     y     z
# 0     None  None  None
# 1     None  None  None
# 2     None  None  None
# 3     None  None  None
# 4     None  None  None
# ...    ...   ...   ...
# 2950  None  None  None
# 2951  None  None  None
# 2952  None  None  None
# 2953  None  None  None
# 2954  None  None  None
#
# [2955 rows x 12 columns]

# %%
def read_df(file):
    sdf = pd.read_csv(file)
    sdf = sdf.rename({"watering": "wateringdesc", "arpae": "arpaedesc", "scenario": "scenariodesc"}, axis=1)
    sdf.columns = [x.replace("sensor_", "").replace("arpae_", "").replace("water_", "") for x in sdf.columns]
    return sdf

# %%
sdf = read_df('data/sensor_ft.csv')
extend_df(sdf, "UniBO", "Forecasting simulation")
sdf.to_csv('data/sensor_enr_ft.csv', index=False)
sdf
# Out:
#                    field                       fielddesc  \
# 0       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4       Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                  ...                             ...
# 354595  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354596  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354597  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354598  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 354599  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                         scenariodesc  \
# 0       Synthetic Bologna 2019 v.2.0
# 1       Synthetic Bologna 2019 v.2.0
# 2       Synthetic Bologna 2019 v.2.0
# 3       Synthetic Bologna 2019 v.2.0
# 4       Synthetic Bologna 2019 v.2.0
# ...                              ...
# 354595  Synthetic Bologna 2019 v.2.0
# 354596  Synthetic Bologna 2019 v.2.0
# 354597  Synthetic Bologna 2019 v.2.0
# 354598  Synthetic Bologna 2019 v.2.0
# 354599  Synthetic Bologna 2019 v.2.0
#
#                                      scenario_description          arpaedesc  \
# 0       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4       Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                   ...                ...
# 354595  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354596  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354597  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354598  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 354599  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                         wateringdesc   timestamp                      type  \
# 0       Synthetic Bologna 2019 v.2.0  1569193200  GROUND_SATURATION_DEGREE
# 1       Synthetic Bologna 2019 v.2.0  1569196800  GROUND_SATURATION_DEGREE
# 2       Synthetic Bologna 2019 v.2.0  1569200400  GROUND_SATURATION_DEGREE
# 3       Synthetic Bologna 2019 v.2.0  1569204000  GROUND_SATURATION_DEGREE
# 4       Synthetic Bologna 2019 v.2.0  1569207600  GROUND_SATURATION_DEGREE
# ...                              ...         ...                       ...
# 354595  Synthetic Bologna 2019 v.2.0  1569175200  GROUND_SATURATION_DEGREE
# 354596  Synthetic Bologna 2019 v.2.0  1569178800  GROUND_SATURATION_DEGREE
# 354597  Synthetic Bologna 2019 v.2.0  1569182400  GROUND_SATURATION_DEGREE
# 354598  Synthetic Bologna 2019 v.2.0  1569186000  GROUND_SATURATION_DEGREE
# 354599  Synthetic Bologna 2019 v.2.0  1569189600  GROUND_SATURATION_DEGREE
#
#           x    y  ...  delay  province region country  owner  \
# 0       0.9  0.0  ...      0        FE     ER      IT  UniBO
# 1       0.9  0.0  ...      0        FE     ER      IT  UniBO
# 2       0.9  0.0  ...      0        FE     ER      IT  UniBO
# 3       0.9  0.0  ...      0        FE     ER      IT  UniBO
# 4       0.9  0.0  ...      0        FE     ER      IT  UniBO
# ...     ...  ...  ...    ...       ...    ...     ...    ...
# 354595  0.9  0.0  ...      0        FE     ER      IT  UniBO
# 354596  0.9  0.0  ...      0        FE     ER      IT  UniBO
# 354597  0.9  0.0  ...      0        FE     ER      IT  UniBO
# 354598  0.9  0.0  ...      0        FE     ER      IT  UniBO
# 354599  0.9  0.0  ...      0        FE     ER      IT  UniBO
#
#                        project            agentType  \
# 0       Forecasting simulation  sensor-(0.9,0,-0.6)
# 1       Forecasting simulation  sensor-(0.9,0,-0.6)
# 2       Forecasting simulation  sensor-(0.9,0,-0.6)
# 3       Forecasting simulation  sensor-(0.9,0,-0.6)
# 4       Forecasting simulation  sensor-(0.9,0,-0.6)
# ...                        ...                  ...
# 354595  Forecasting simulation  sensor-(0.9,0,-0.6)
# 354596  Forecasting simulation  sensor-(0.9,0,-0.6)
# 354597  Forecasting simulation  sensor-(0.9,0,-0.6)
# 354598  Forecasting simulation  sensor-(0.9,0,-0.6)
# 354599  Forecasting simulation  sensor-(0.9,0,-0.6)
#
#                                  agent       agentHier  \
# 0       sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 1       sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 2       sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 3       sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 4       sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# ...                                ...             ...
# 354595  sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 354596  sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 354597  sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 354598  sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
# 354599  sensor-(0.9,0,-0.6)-0d02000d12  AssignedDevice
#
#                                      type-ext
# 0       GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 1       GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 2       GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 3       GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 4       GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# ...                                       ...
# 354595  GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 354596  GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 354597  GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 354598  GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
# 354599  GROUND_SATURATION_DEGREE-(0.9,0,-0.6)
#
# [354600 rows x 28 columns]

# %%
wdf = read_df('data/weather_ft.csv')
extend_df(wdf, "UniBO", "Forecasting simulation")
wdf.to_csv('data/weather_enr_ft.csv', index=False)
wdf
# Out:
#                   field                       fielddesc  \
# 0      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4      Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                 ...                             ...
# 14770  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14771  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14772  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14773  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 14774  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                        scenariodesc  \
# 0      Synthetic Bologna 2019 v.2.0
# 1      Synthetic Bologna 2019 v.2.0
# 2      Synthetic Bologna 2019 v.2.0
# 3      Synthetic Bologna 2019 v.2.0
# 4      Synthetic Bologna 2019 v.2.0
# ...                             ...
# 14770  Synthetic Bologna 2019 v.2.0
# 14771  Synthetic Bologna 2019 v.2.0
# 14772  Synthetic Bologna 2019 v.2.0
# 14773  Synthetic Bologna 2019 v.2.0
# 14774  Synthetic Bologna 2019 v.2.0
#
#                                     scenario_description          arpaedesc  \
# 0      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4      Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                  ...                ...
# 14770  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14771  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14772  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14773  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 14774  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                        wateringdesc   timestamp            type  value   x  \
# 0      Synthetic Bologna 2019 v.2.0  1559340000  PRECIPITATIONS    0.0 NaN
# 1      Synthetic Bologna 2019 v.2.0  1559343600  PRECIPITATIONS    0.0 NaN
# 2      Synthetic Bologna 2019 v.2.0  1559347200  PRECIPITATIONS    0.0 NaN
# 3      Synthetic Bologna 2019 v.2.0  1559350800  PRECIPITATIONS    0.0 NaN
# 4      Synthetic Bologna 2019 v.2.0  1559354400  PRECIPITATIONS    0.0 NaN
# ...                             ...         ...             ...    ...  ..
# 14770  Synthetic Bologna 2019 v.2.0  1569960000      WIND_SPEED    2.8 NaN
# 14771  Synthetic Bologna 2019 v.2.0  1569963600      WIND_SPEED    2.6 NaN
# 14772  Synthetic Bologna 2019 v.2.0  1569967200      WIND_SPEED    3.1 NaN
# 14773  Synthetic Bologna 2019 v.2.0  1569970800      WIND_SPEED    5.1 NaN
# 14774  Synthetic Bologna 2019 v.2.0  1569974400      WIND_SPEED    4.0 NaN
#
#        ...  delay  province region country  owner                 project  \
# 0      ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 1      ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 2      ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 3      ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 4      ...      0        FE     ER      IT  UniBO  Forecasting simulation
# ...    ...    ...       ...    ...     ...    ...                     ...
# 14770  ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 14771  ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 14772  ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 14773  ...      0        FE     ER      IT  UniBO  Forecasting simulation
# 14774  ...      0        FE     ER      IT  UniBO  Forecasting simulation
#
#             agentType                      agent       agentHier  \
# 0      PRECIPITATIONS  PRECIPITATIONS-0d02000d12  AssignedDevice
# 1      PRECIPITATIONS  PRECIPITATIONS-0d02000d12  AssignedDevice
# 2      PRECIPITATIONS  PRECIPITATIONS-0d02000d12  AssignedDevice
# 3      PRECIPITATIONS  PRECIPITATIONS-0d02000d12  AssignedDevice
# 4      PRECIPITATIONS  PRECIPITATIONS-0d02000d12  AssignedDevice
# ...               ...                        ...             ...
# 14770  WeatherStation  WeatherStation-0d02000d12  AssignedDevice
# 14771  WeatherStation  WeatherStation-0d02000d12  AssignedDevice
# 14772  WeatherStation  WeatherStation-0d02000d12  AssignedDevice
# 14773  WeatherStation  WeatherStation-0d02000d12  AssignedDevice
# 14774  WeatherStation  WeatherStation-0d02000d12  AssignedDevice
#
#              type-ext
# 0      PRECIPITATIONS
# 1      PRECIPITATIONS
# 2      PRECIPITATIONS
# 3      PRECIPITATIONS
# 4      PRECIPITATIONS
# ...               ...
# 14770      WIND_SPEED
# 14771      WIND_SPEED
# 14772      WIND_SPEED
# 14773      WIND_SPEED
# 14774      WIND_SPEED
#
# [14775 rows x 28 columns]

# %%
idf = read_df('data/irrigation_ft.csv')
extend_df(idf, "UniBO", "Forecasting simulation")
idf.to_csv('data/irrigation_enr_ft.csv', index=False)
idf
# Out:
#                  field                       fielddesc  \
# 0     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 1     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 3     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 4     Field-0d02000d12  Synthetic field PROGETTO v.1.0
# ...                ...                             ...
# 2950  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2951  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2952  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2953  Field-0d02000d12  Synthetic field PROGETTO v.1.0
# 2954  Field-0d02000d12  Synthetic field PROGETTO v.1.0
#
#                       scenariodesc  \
# 0     Synthetic Bologna 2019 v.2.0
# 1     Synthetic Bologna 2019 v.2.0
# 2     Synthetic Bologna 2019 v.2.0
# 3     Synthetic Bologna 2019 v.2.0
# 4     Synthetic Bologna 2019 v.2.0
# ...                            ...
# 2950  Synthetic Bologna 2019 v.2.0
# 2951  Synthetic Bologna 2019 v.2.0
# 2952  Synthetic Bologna 2019 v.2.0
# 2953  Synthetic Bologna 2019 v.2.0
# 2954  Synthetic Bologna 2019 v.2.0
#
#                                    scenario_description          arpaedesc  \
# 0     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 1     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 3     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 4     Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# ...                                                 ...                ...
# 2950  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2951  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2952  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2953  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
# 2954  Real arpae data from 01.06.2019 to 01.10.2019 ...  Real Bologna 2019
#
#                       wateringdesc   timestamp         type  value   x  ...  \
# 0     Synthetic Bologna 2019 v.2.0  1559340000  IRRIGATIONS    0.0 NaN  ...
# 1     Synthetic Bologna 2019 v.2.0  1559343600  IRRIGATIONS    0.0 NaN  ...
# 2     Synthetic Bologna 2019 v.2.0  1559347200  IRRIGATIONS    0.0 NaN  ...
# 3     Synthetic Bologna 2019 v.2.0  1559350800  IRRIGATIONS    0.0 NaN  ...
# 4     Synthetic Bologna 2019 v.2.0  1559354400  IRRIGATIONS    0.0 NaN  ...
# ...                            ...         ...          ...    ...  ..  ...
# 2950  Synthetic Bologna 2019 v.2.0  1569960000  IRRIGATIONS    0.0 NaN  ...
# 2951  Synthetic Bologna 2019 v.2.0  1569963600  IRRIGATIONS    0.0 NaN  ...
# 2952  Synthetic Bologna 2019 v.2.0  1569967200  IRRIGATIONS    0.0 NaN  ...
# 2953  Synthetic Bologna 2019 v.2.0  1569970800  IRRIGATIONS    0.0 NaN  ...
# 2954  Synthetic Bologna 2019 v.2.0  1569974400  IRRIGATIONS    0.0 NaN  ...
#
#       delay  province region country  owner                 project  \
# 0         0        FE     ER      IT  UniBO  Forecasting simulation
# 1         0        FE     ER      IT  UniBO  Forecasting simulation
# 2         0        FE     ER      IT  UniBO  Forecasting simulation
# 3         0        FE     ER      IT  UniBO  Forecasting simulation
# 4         0        FE     ER      IT  UniBO  Forecasting simulation
# ...     ...       ...    ...     ...    ...                     ...
# 2950      0        FE     ER      IT  UniBO  Forecasting simulation
# 2951      0        FE     ER      IT  UniBO  Forecasting simulation
# 2952      0        FE     ER      IT  UniBO  Forecasting simulation
# 2953      0        FE     ER      IT  UniBO  Forecasting simulation
# 2954      0        FE     ER      IT  UniBO  Forecasting simulation
#
#         agentType                   agent       agentHier     type-ext
# 0     IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 1     IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 2     IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 3     IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 4     IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# ...           ...                     ...             ...          ...
# 2950  IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 2951  IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 2952  IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 2953  IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
# 2954  IRRIGATIONS  IRRIGATIONS-0d02000d12  AssignedDevice  IRRIGATIONS
#
# [2955 rows x 28 columns]

# %%
tables = get_tables()
tables["dt_field"]["json"] = ["fielddesc", "scenariodesc", "scenario_description", "arpaedesc", "wateringdesc"]
tables["dt_agent"]["json"] = ["x", "y", "z"]

columns = get_columns(tables)
edf = pd.concat([sdf[columns], idf[columns], wdf[columns]], ignore_index=True)

# %%
db_name2 = config["OUT_DB"]

# %%
from psycopg2 import sql

try: 
    conn = connect(config["IN_DB"])
    # Create a cursor
    cursor = conn.cursor()
    # Define the SQL command to create the database (if not exists)
    create_db_query = sql.SQL("CREATE DATABASE {};").format(sql.Identifier(db_name2))
    # Execute the SQL command
    cursor.execute(create_db_query)
    # Commit the changes and close the connection
    conn.commit()
    cursor.close()
    conn.close()
except:
    print("DB already exists")

db_params['database'] = db_name2
conn_str = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(**db_params)
engine = create_engine(conn_str)

conn = connect(db_name2)
cursor = conn.cursor()

for tablename, columns in tables.items():
    print(tablename)
    try: 
        create_db_query = sql.SQL("DROP TABLE {} CASCADE;").format(sql.Identifier(tablename))
        cursor.execute(create_db_query)
        conn.commit()
    except:
        print("Table {} does not exist".format(tablename))
    
    try: 
        df = edf[columns["col"]]
        compute_json(df, edf, columns)
        df[columns["col"] + ["rawJSON"]].drop_duplicates().to_sql(tablename, engine, if_exists='replace', index=False)
    except Exception as e:
        print(e) 
        print("FAIL to create {}".format(tablename))


for statement in [
    "ALTER TABLE dt_time ADD PRIMARY KEY (timestamp);",
    "ALTER TABLE dt_field ADD PRIMARY KEY (field);",
    "ALTER TABLE dt_agent ADD PRIMARY KEY (agent);",
    "ALTER TABLE ft_measurement ADD PRIMARY KEY (timestamp, field, agent, project, type, owner);",
    "ALTER TABLE ft_measurement ADD FOREIGN KEY (timestamp) REFERENCES dt_time(timestamp);",
    "ALTER TABLE ft_measurement ADD FOREIGN KEY (field) REFERENCES dt_field(field);",
    "ALTER TABLE ft_measurement ADD FOREIGN KEY (agent) REFERENCES dt_agent(agent);"
    ]:
    try: 
        print(statement)
        create_db_query = sql.SQL(statement)
        cursor.execute(create_db_query)
        conn.commit()
    except Exception as e:
        print(e) 

cursor.close()
conn.close()
# Out:
# DB already exists
# dt_field
# d:\OneDrive - Alma Mater Studiorum Università di Bologna\Documents\repos\watering-extract\shared.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rawJSON"] = df_all[list(set(jso) & set(list(df_all.columns)))].apply(lambda row: row_to_json(row), axis=1)
# dt_time
# d:\OneDrive - Alma Mater Studiorum Università di Bologna\Documents\repos\watering-extract\shared.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rawJSON"] = json.dumps({})
# dt_agent
# d:\OneDrive - Alma Mater Studiorum Università di Bologna\Documents\repos\watering-extract\shared.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rawJSON"] = df_all[list(set(jso) & set(list(df_all.columns)))].apply(lambda row: row_to_json(row), axis=1)
# d:\OneDrive - Alma Mater Studiorum Università di Bologna\Documents\repos\watering-extract\shared.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rawJSON"] = json.dumps({})
# ft_measurement
# ALTER TABLE dt_time ADD PRIMARY KEY (timestamp);
# ALTER TABLE dt_field ADD PRIMARY KEY (field);
# ALTER TABLE dt_agent ADD PRIMARY KEY (agent);
# ALTER TABLE ft_measurement ADD PRIMARY KEY (timestamp, field, agent, project, type, owner);
# ALTER TABLE ft_measurement ADD FOREIGN KEY (timestamp) REFERENCES dt_time(timestamp);
# ALTER TABLE ft_measurement ADD FOREIGN KEY (field) REFERENCES dt_field(field);
# ALTER TABLE ft_measurement ADD FOREIGN KEY (agent) REFERENCES dt_agent(agent);

# %%
tables = {
    "ft_field_measurement": {"col": ["type-ext", "field", "owner", "project", "timestamp", "value"]}
}

columns = get_columns(tables)
rdf = pd.concat([sdf[columns], idf[columns], wdf[columns]], ignore_index=True)
rdf = rdf.rename({"type-ext": "type"}, axis=1)
print(rdf[["field", "timestamp", "type", "owner", "project", "value"]].groupby(["field", "timestamp", "type", "owner", "project"]).filter(lambda group: len(group) > 1))
pivoted_df = rdf[["field", "timestamp", "type", "owner", "project", "value"]]
pivoted_df["timestamp"] = pivoted_df["timestamp"].apply(lambda x: int(x / 3600) * 3600)
pivoted_df = pivoted_df.groupby(["field", "timestamp", "type", "owner", "project", "value"]).mean().reset_index()
pivoted_df
# Out:
# Empty DataFrame
# Columns: [field, timestamp, type, owner, project, value]
# Index: []
#                    field   timestamp                                 type  \
# 0       Field-0d02000d12  1559340000                         AIR_HUMIDITY
# 1       Field-0d02000d12  1559340000                      AIR_TEMPERATURE
# 2       Field-0d02000d12  1559340000  GROUND_SATURATION_DEGREE-(0,0,-0.1)
# 3       Field-0d02000d12  1559340000  GROUND_SATURATION_DEGREE-(0,0,-0.2)
# 4       Field-0d02000d12  1559340000  GROUND_SATURATION_DEGREE-(0,0,-0.3)
# ...                  ...         ...                                  ...
# 372325  Field-0d02000d12  1569974400  GROUND_WATER_POTENTIAL-(0.9,0,-0.6)
# 372326  Field-0d02000d12  1569974400                          IRRIGATIONS
# 372327  Field-0d02000d12  1569974400                       PRECIPITATIONS
# 372328  Field-0d02000d12  1569974400                           RADIATIONS
# 372329  Field-0d02000d12  1569974400                           WIND_SPEED
#
#         owner                 project     value
# 0       UniBO  Forecasting simulation   49.0000
# 1       UniBO  Forecasting simulation   17.3000
# 2       UniBO  Forecasting simulation    0.2597
# 3       UniBO  Forecasting simulation    0.2487
# 4       UniBO  Forecasting simulation    0.2465
# ...       ...                     ...       ...
# 372325  UniBO  Forecasting simulation -299.1410
# 372326  UniBO  Forecasting simulation    0.0000
# 372327  UniBO  Forecasting simulation    0.0000
# 372328  UniBO  Forecasting simulation   -2.0000
# 372329  UniBO  Forecasting simulation    4.0000
#
# [372330 rows x 6 columns]

# %%
pivoted_df = pivoted_df.pivot(index=["field", "timestamp", "owner", "project"], columns='type', values='value')
pivoted_df.reset_index(inplace=True)
# pivoted_df = pivoted_df.dropna(axis=1, how='all').fillna(method='ffill').fillna(method='bfill').dropna()
pivoted_df
# Out:
# type             field   timestamp  owner                 project  \
# 0     Field-0d02000d12  1559340000  UniBO  Forecasting simulation
# 1     Field-0d02000d12  1559343600  UniBO  Forecasting simulation
# 2     Field-0d02000d12  1559347200  UniBO  Forecasting simulation
# 3     Field-0d02000d12  1559350800  UniBO  Forecasting simulation
# 4     Field-0d02000d12  1559354400  UniBO  Forecasting simulation
# ...                ...         ...    ...                     ...
# 2950  Field-0d02000d12  1569960000  UniBO  Forecasting simulation
# 2951  Field-0d02000d12  1569963600  UniBO  Forecasting simulation
# 2952  Field-0d02000d12  1569967200  UniBO  Forecasting simulation
# 2953  Field-0d02000d12  1569970800  UniBO  Forecasting simulation
# 2954  Field-0d02000d12  1569974400  UniBO  Forecasting simulation
#
# type  AIR_HUMIDITY  AIR_TEMPERATURE  GROUND_SATURATION_DEGREE-(0,0,-0.1)  \
# 0             49.0             17.3                               0.2597
# 1             50.0             16.7                               0.2593
# 2             49.0             16.4                               0.2590
# 3             52.0             15.6                               0.2587
# 4             52.0             15.2                               0.2584
# ...            ...              ...                                  ...
# 2950          54.0             22.0                               0.3148
# 2951          53.0             21.9                               0.3120
# 2952          56.0             20.9                               0.3093
# 2953          52.0             21.0                               0.3069
# 2954          53.0             21.0                               0.3045
#
# type  GROUND_SATURATION_DEGREE-(0,0,-0.2)  \
# 0                                  0.2487
# 1                                  0.2487
# 2                                  0.2487
# 3                                  0.2488
# 4                                  0.2488
# ...                                   ...
# 2950                               0.2997
# 2951                               0.2973
# 2952                               0.2950
# 2953                               0.2928
# 2954                               0.2907
#
# type  GROUND_SATURATION_DEGREE-(0,0,-0.3)  \
# 0                                  0.2465
# 1                                  0.2464
# 2                                  0.2463
# 3                                  0.2462
# 4                                  0.2462
# ...                                   ...
# 2950                               0.2730
# 2951                               0.2714
# 2952                               0.2700
# 2953                               0.2685
# 2954                               0.2671
#
# type  GROUND_SATURATION_DEGREE-(0,0,-0.4)  ...  \
# 0                                  0.2486  ...
# 1                                  0.2484  ...
# 2                                  0.2482  ...
# 3                                  0.2480  ...
# 4                                  0.2478  ...
# ...                                   ...  ...
# 2950                               0.1987  ...
# 2951                               0.1997  ...
# 2952                               0.2006  ...
# 2953                               0.2013  ...
# 2954                               0.2020  ...
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.1)  \
# 0                                 -27.463
# 1                                 -27.525
# 2                                 -27.587
# 3                                 -27.645
# 4                                 -27.705
# ...                                   ...
# 2950                             -118.920
# 2951                             -119.134
# 2952                             -119.359
# 2953                             -119.691
# 2954                             -119.982
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.2)  \
# 0                                 -29.959
# 1                                 -29.954
# 2                                 -29.947
# 3                                 -29.935
# 4                                 -29.925
# ...                                   ...
# 2950                             -328.317
# 2951                             -328.542
# 2952                             -328.781
# 2953                             -329.449
# 2954                             -329.910
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.3)  \
# 0                                 -30.524
# 1                                 -30.526
# 2                                 -30.532
# 3                                 -30.535
# 4                                 -30.541
# ...                                   ...
# 2950                            -1313.009
# 2951                            -1311.611
# 2952                            -1310.224
# 2953                            -1309.067
# 2954                            -1307.806
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.4)  \
# 0                                 -29.981
# 1                                 -30.009
# 2                                 -30.039
# 3                                 -30.068
# 4                                 -30.098
# ...                                   ...
# 2950                            -1530.046
# 2951                            -1529.862
# 2952                            -1529.678
# 2953                            -1529.528
# 2954                            -1529.360
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.5)  \
# 0                                 -29.751
# 1                                 -29.776
# 2                                 -29.802
# 3                                 -29.826
# 4                                 -29.851
# ...                                   ...
# 2950                            -1058.754
# 2951                            -1058.382
# 2952                            -1058.017
# 2953                            -1057.777
# 2954                            -1057.477
#
# type  GROUND_WATER_POTENTIAL-(0.9,0,-0.6)  IRRIGATIONS  PRECIPITATIONS  \
# 0                                 -29.906          0.0             0.0
# 1                                 -29.856          0.0             0.0
# 2                                 -29.819          0.0             0.0
# 3                                 -29.791          0.0             0.0
# 4                                 -29.770          0.0             0.0
# ...                                   ...          ...             ...
# 2950                             -299.282          0.0             0.0
# 2951                             -299.231          0.0             0.0
# 2952                             -299.183          0.0             0.0
# 2953                             -299.170          0.0             0.0
# 2954                             -299.141          0.0             0.0
#
# type  RADIATIONS  WIND_SPEED
# 0           -2.0         2.9
# 1           -5.0         3.7
# 2           -4.0         4.0
# 3           -1.0         4.4
# 4           -2.0         4.6
# ...          ...         ...
# 2950        -3.0         2.8
# 2951        -7.0         2.6
# 2952        -2.0         3.1
# 2953        -2.0         5.1
# 2954        -2.0         4.0
#
# [2955 rows x 130 columns]

# %%
conn = connect(db_name2)
cursor = conn.cursor()

db_params['database'] = db_name2
conn_str = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(**db_params)
engine = create_engine(conn_str)

tablename = "ft_field_measurement"
try: 
    create_db_query = sql.SQL("DROP TABLE {};").format(sql.Identifier(tablename))
    cursor.execute(create_db_query)
    conn.commit()
except Exception as e:
    print(e)

try: 
    pivoted_df.drop_duplicates().to_sql(tablename, engine, if_exists='replace', index=False)
except Exception as e:
    print(e) 
    print("FAIL to create {}".format(tablename))


for statement in [
    "ALTER TABLE ft_field_measurement ADD PRIMARY KEY (timestamp, field, owner);",
    "ALTER TABLE ft_field_measurement ADD FOREIGN KEY (timestamp) REFERENCES dt_time(timestamp);",
    "ALTER TABLE ft_field_measurement ADD FOREIGN KEY (field) REFERENCES dt_field(field);",
    ]:
    try: 
        print(statement)
        create_db_query = sql.SQL(statement)
        cursor.execute(create_db_query)
        conn.commit()
    except Exception as e:
        print(e) 

cursor.close()
conn.close()
# Out:
# ALTER TABLE ft_field_measurement ADD PRIMARY KEY (timestamp, field, owner);
# ALTER TABLE ft_field_measurement ADD FOREIGN KEY (timestamp) REFERENCES dt_time(timestamp);
# ALTER TABLE ft_field_measurement ADD FOREIGN KEY (field) REFERENCES dt_field(field);
